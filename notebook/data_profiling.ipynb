# %%
import numpy as np
import pandas as pd
import os
import sys
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)
from src.data_profiling import InclusionDataProfiler

# %%
df = pd.read_csv("../data/raw/ethiopia_fi_unified_data.csv", index_col=0, parse_dates=True)
impact_df = pd.read_csv("../data/raw/Impact_sheet.csv", index_col=0, parse_dates=True)
# Out:
# C:\Users\Birhanu Matebe\AppData\Local\Temp\ipykernel_16540\337708288.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("../data/raw/ethiopia_fi_unified_data.csv", index_col=0, parse_dates=True)
# C:\Users\Birhanu Matebe\AppData\Local\Temp\ipykernel_16540\337708288.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   impact_df = pd.read_csv("../data/raw/Impact_sheet.csv", index_col=0, parse_dates=True)

# %%
# --- Execution ---
profiler = InclusionDataProfiler(df, impact_df)
profiler.run_all()
# Out:
# ====== SCHEMA & RECORD TYPE SUMMARY ======
#              Count
# record_type
# event           10
# observation     30
# target           3
# --- Pillar Distribution ---
#                Count
# pillar
# ACCESS            16
# USAGE             11
# GENDER             5
# AFFORDABILITY      1
# ====== TEMPORAL RANGE ======
# Observations Range: 2014-12-31 to 2025-12-31
# Total Events Cataloged: 10
#                                         indicator observation_date
# record_id
# EVT_0001                          Telebirr Launch       2021-05-17
# EVT_0009                  NFIS-II Strategy Launch       2021-09-01
# EVT_0002     Safaricom Ethiopia Commercial Launch       2022-08-01
# EVT_0003                   M-Pesa Ethiopia Launch       2023-08-01
# EVT_0004         Fayda Digital ID Program Rollout       2024-01-01
# EVT_0005          Foreign Exchange Liberalization       2024-07-29
# EVT_0006      P2P Transaction Count Surpasses ATM       2024-10-01
# ...
